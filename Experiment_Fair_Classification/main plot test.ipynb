# %%
import torch
import pickle
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from functions import shadowplot
import numpy as np
#example of pickle
# l = [1,2,3,4]
# with open("test", "wb") as fp:   #Pickling
#     pickle.dump(l, fp)

# with open("test", "rb") as fp:   # Unpickling
#     b = pickle.load(fp)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.cuda.get_device_name(0)

theta = 0.8
theta_vr = 0.8
data_name = 'MNIST'
#data_name = 'F-MNIST'
#data_name = 'CIFAR10'
data_path = './result_data/'+ data_name 
G = {}
# G['SAPD'] = data_path +'/SAPD_' + 'theta=0.' + str(int(theta*100))
# G['SAPD-x'] = data_path +'/SAPDx_' + 'theta=0.' + str(int(0.8*100))
G['SAPD-VR'] = data_path +'/SAPD_VR_' + 'theta=0.' + str(int(theta_vr*100))
# G['SAPD-x-VR'] = data_path +'SAPDx_VR_' + 'theta=0.' + str(int(theta*100))
# G['SMDA'] = data_path +'/SMDA'
G['SMDA-VR'] = data_path +'/SMDA_VR'
G['SREDA'] = data_path +'/SREDA'
# G['PASGDA'] = data_path +'/PASGDA'


plt.figure(dpi=150)
fig, ax = plt.subplots() 
C = 0
is_log = True
for alg_name, file_name in G.items():
    print(alg_name)
    with open(file_name, "rb") as fp:   # Unpickling
        loss,epoch = pickle.load(fp)
    
    shadowplot(epoch,loss,label_input=alg_name,alpha=0.1,center=C,alg_name=alg_name,is_log = is_log)

#plt.legend(loc='lower center')
plt.legend(fontsize = 15, loc='upper right')
plt.xlabel("Epoch", fontsize = 15)
plt.ylabel("Loss",fontsize = 15)
plt.rc('xtick', labelsize=15)    
plt.rc('ytick', labelsize=15) 

plt.xlim(0,100)
if is_log:
    ax.set_yticklabels([round(np.exp(y)+C,2) for y in ax.get_yticks()]) 
    plt.ylim(1.065,1.12)
else:
    ax.set_yticklabels([round(y,2) for y in ax.get_yticks()]) 
    plt.ylim(2.9,3.1)
plt.grid()
#mpl.rcParams.update({'font.size': 14})
plt.title('MNIST',fontsize=15)
plt.savefig('./figure/MNIST.png',bbox_inches='tight',facecolor='w',dpi=1200)
#plt.clf()
# Out:
# SAPD-VR
# SMDA-VR
# SREDA
# C:\Users\Xuan\AppData\Local\Temp/ipykernel_7020/1954895560.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(np.exp(y)+C,2) for y in ax.get_yticks()])

# %%
import torch
import pickle
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from functions import shadowplot
import numpy as np
#example of pickle
# l = [1,2,3,4]
# with open("test", "wb") as fp:   #Pickling
#     pickle.dump(l, fp)

# with open("test", "rb") as fp:   # Unpickling
#     b = pickle.load(fp)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.cuda.get_device_name(0)

theta = 0.8
theta_vr = 0.8
# data_name = 'MNIST'
data_name = 'F-MNIST'
#data_name = 'CIFAR10'
data_path = './result_data/'+ data_name 
G = {}
# G['SAPD'] = data_path +'/SAPD_' + 'theta=0.' + str(int(theta*100))
# G['SAPD-x'] = data_path +'/SAPDx_' + 'theta=0.' + str(int(0.8*100))
G['SAPD-VR'] = data_path +'/SAPD_VR_' + 'theta=0.' + str(int(theta_vr*100))
# G['SAPD-x-VR'] = data_path +'SAPDx_VR_' + 'theta=0.' + str(int(theta*100))
# G['SMDA'] = data_path +'/SMDA'
G['SMDA-VR'] = data_path +'/SMDA_VR'
G['SREDA'] = data_path +'/SREDA'
# G['PASGDA'] = data_path +'/PASGDA'


plt.figure(dpi=150)
fig, ax = plt.subplots() 
C = 2.85

for alg_name, file_name in G.items():

    with open(file_name, "rb") as fp:   # Unpickling
        loss,epoch = pickle.load(fp)

        shadowplot(epoch,loss,label_input=alg_name,alpha=0.1,center=C,is_log=True,alg_name=alg_name)
#plt.legend(loc='lower center')
plt.legend(fontsize = 15, loc='upper right')
plt.xlabel("Epoch", fontsize = 15)
plt.ylabel("Loss",fontsize = 15)
plt.rc('xtick', labelsize=15)    
plt.rc('ytick', labelsize=15) 

plt.xlim(0,100)
plt.ylim(-3.1,-1.5)
ax.set_yticklabels([round(np.exp(y)+C,2) for y in ax.get_yticks()]) 

plt.grid()
#mpl.rcParams.update({'font.size': 14})
plt.title('F-MNIST',fontsize = 15)
plt.savefig('./figure/F-MNIST.png',bbox_inches='tight',facecolor='w',dpi=1200)
#plt.clf()
# Out:
# C:\Users\Xuan\AppData\Local\Temp/ipykernel_7020/4009292206.py:53: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(np.exp(y)+C,2) for y in ax.get_yticks()])

# %%
import torch
import pickle
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from functions import shadowplot
import numpy as np
#example of pickle
# l = [1,2,3,4]
# with open("test", "wb") as fp:   #Pickling
#     pickle.dump(l, fp)

# with open("test", "rb") as fp:   # Unpickling
#     b = pickle.load(fp)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.cuda.get_device_name(0)

theta = 0.98
theta_vr = 0.8
# data_name = 'MNIST'
#data_name = 'F-MNIST'
data_name = 'CIFAR10'
data_path = './result_data/'+ data_name 
G = {}
# G['SAPD'] = data_path +'/SAPD_VR_' + 'theta=0.' + str(int(theta*100))
# G['SAPD-x'] = data_path +'/SAPDx_' + 'theta=0.' + str(int(0.8*100))
G['SAPD-VR'] = data_path +'/SAPD_VR_' + 'theta=0.' + str(int(theta_vr*100))
# G['SAPD-x-VR'] = data_path +'SAPDx_VR_' + 'theta=0.' + str(int(theta*100))
# G['SMDA'] = data_path +'/SMDA'
G['SMDA-VR'] = data_path +'/SMDA_VR'
G['SREDA'] = data_path +'/SREDA'
# G['PASGDA'] = data_path +'/PASGDA'

is_log = True
plt.figure(dpi=150)
fig, ax = plt.subplots() 
C = 2.5
for alg_name, file_name in G.items():

    with open(file_name, "rb") as fp:   # Unpickling
        loss,epoch = pickle.load(fp)
    
    shadowplot(epoch,loss,label_input=alg_name,alpha=0.1,center=C,is_log=is_log ,is_var=False,alg_name=alg_name)

#plt.legend(loc='lower center')
plt.legend(fontsize = 15, loc='upper right')
plt.xlabel("Epoch", fontsize = 15)
plt.ylabel("Loss",fontsize = 15)
plt.rc('xtick', labelsize=15)    
plt.rc('ytick', labelsize=15) 


plt.xlim(0,100)
if is_log:
    ax.set_yticklabels([round(np.exp(y)+C,2) for y in ax.get_yticks()]) 
    plt.ylim(-0.71,-0.35)
else:
    ax.set_yticklabels([round(y,1) for y in ax.get_yticks()]) 
    plt.ylim(2.99,3.2)

plt.grid()
#mpl.rcParams.update({'font.size': 14})
plt.title('CIFAR10',fontsize=15)
plt.savefig('./figure/CIFAR10.png',bbox_inches='tight',facecolor='w',dpi=1200)
#plt.clf()
# Out:
# C:\Users\Xuan\AppData\Local\Temp/ipykernel_7020/1544189929.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(np.exp(y)+C,2) for y in ax.get_yticks()])
